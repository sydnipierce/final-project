# %% [markdown]
# Connect to Spark and read in the data from the csv file (using the Amazon Web Services S3 url)

# %%
import os
# Find the latest version of spark 3.0  from http://www-us.apache.org/dist/spark/ and enter as the spark version
# For example:
# spark_version = 'spark-3.0.2'
spark_version = 'spark-3.1.2' #<enter version>'
os.environ['SPARK_VERSION']=spark_version

# Install Spark and Java
# !apt-get update
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q https://downloads.apache.org/spark/$SPARK_VERSION/$SPARK_VERSION-bin-hadoop2.7.tgz
# !tar xf $SPARK_VERSION-bin-hadoop2.7.tgz
# !pip install -q findspark

# Set Environment Variables
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = f"/content/{spark_version}-bin-hadoop2.7"

# Start a SparkSession
import findspark
findspark.init()
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,294 kB]
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:14 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [543 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,424 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:17 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:19 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,794 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,730 kB]
# Get:21 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [918 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,199 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [575 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [34.4 kB]
# Fetched 12.8 MB in 4s (3,166 kB/s)
# Reading package lists... Done

# %%
# Start Spark session
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Hashing1").getOrCreate()

# %%
from pyspark.ml.feature import HashingTF, IDF, Tokenizer, StopWordsRemover
from pyspark.sql.functions import col, udf
from pyspark.sql.types import IntegerType

# %%
# Read in data from S3 Buckets
from pyspark import SparkFiles
url ="https://butlerunit22.s3.us-east-2.amazonaws.com/all_articles_final.csv"
spark.sparkContext.addFile(url)
news_import_df = spark.read.csv(SparkFiles.get("all_articles_final.csv"), sep=",", header=True)

# Show DataFrame
news_import_df =.show()
# Out:
# +---+----+---------+--------------------+--------------------+-------+-----------------+
# |_c0|type|news_type|               title|                text|subject|             date|
# +---+----+---------+--------------------+--------------------+-------+-----------------+
# |  0|   0|     fake| Donald Trump Sen...|Donald Trump just...|   News|December 31, 2017|
# |  1|   0|     fake| Drunk Bragging T...|House Intelligenc...|   News|December 31, 2017|
# |  2|   0|     fake| Sheriff David Cl...|On Friday, it was...|   News|December 30, 2017|
# |  3|   0|     fake| Trump Is So Obse...|On Christmas day,...|   News|December 29, 2017|
# |  4|   0|     fake| Pope Francis Jus...|Pope Francis used...|   News|December 25, 2017|
# |  5|   0|     fake| Racist Alabama C...|The number of cas...|   News|December 25, 2017|
# |  6|   0|     fake| Fresh Off The Go...|Donald Trump spen...|   News|December 23, 2017|
# |  7|   0|     fake| Trump Said Some ...|In the wake of ye...|   News|December 23, 2017|
# |  8|   0|     fake| Former CIA Direc...|Many people have ...|   News|December 22, 2017|
# |  9|   0|     fake| WATCH: Brand-New...|Just when you mig...|   News|December 21, 2017|
# | 10|   0|     fake| Papa John’s Foun...|A centerpiece of ...|   News|December 21, 2017|
# | 11|   0|     fake| WATCH: Paul Ryan...|Republicans are w...|   News|December 21, 2017|
# | 12|   0|     fake| Bad News For Tru...|Republicans have ...|   News|December 21, 2017|
# | 13|   0|     fake| WATCH: Lindsey G...|The media has bee...|   News|December 20, 2017|
# | 14|   0|     fake| Heiress To Disne...|Abigail Disney is...|   News|December 20, 2017|
# | 15|   0|     fake| Tone Deaf Trump:...|Donald Trump just...|   News|December 20, 2017|
# | 16|   0|     fake| The Internet Bru...|A new animatronic...|   News|December 19, 2017|
# | 17|   0|     fake| Mueller Spokesma...|Trump supporters ...|   News|December 17, 2017|
# | 18|   0|     fake| SNL Hilariously ...|Right now, the wh...|   News|December 17, 2017|
# | 19|   0|     fake| Republican Senat...|Senate Majority W...|   News|December 16, 2017|
# +---+----+---------+--------------------+--------------------+-------+-----------------+
# only showing top 20 rows

# %%
news_import_df = news_import_df.dropDuplicates()

mf = news_import_df.groupby('news_type')
news_import_df.count()
# Out:
# 44230

# %%
cleaned = news_import_df.filter((news_import_df['news_type'] == 'fake') | (news_import_df['news_type'] == 'true') )
cleaned.count()
# Out:
# 44226

# %%
mfc = cleaned.groupby('news_type')
mfc.count().show()
# Out:
# +---------+-----+
# |news_type|count|
# +---------+-----+
# |     fake|22838|
# |     true|21388|
# +---------+-----+

# %%
# export into Pandas
import pandas as pd

pd_df = cleaned.toPandas()

# %%
from sklearn import preprocessing
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder()
# Encode labels in column 'Country'. 
pd_df['news_code']= label_encoder.fit_transform(pd_df['news_type']) 
print(pd_df.head())
# Out:
#    _c0 type news_type  ... subject              date news_code
# 0  203    0      fake  ...    News  October 20, 2017         0
# 1  226    0      fake  ...    News  October 12, 2017         0
# 2  461    0      fake  ...    News   August 31, 2017         0
# 3  617    0      fake  ...    News    August 9, 2017         0
# 4  683    0      fake  ...    News    August 2, 2017         0
#
# [5 rows x 8 columns]

# %%
data = pd_df["text"]
labels = pd_df['news_code']

# %%
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split, GridSearchCV

text_clf = Pipeline([('vect', CountVectorizer()),
                     ('tfidf', TfidfTransformer()),
                     ('clf', MultinomialNB())])

tuned_parameters = {
    'vect__ngram_range': [(1, 1), (1, 2), (2, 2)],
    'tfidf__use_idf': (True, False),
    'tfidf__norm': ('l1', 'l2'),
    'clf__alpha': [1, 1e-1, 1e-2]
}

x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.33, random_state=42)

# %%
from sklearn.metrics import classification_report

clf = GridSearchCV(text_clf, tuned_parameters, cv=10, verbose=3)#, scoring=score)


clf.fit(x_train, y_train)

classification_report(y_test, clf.predict(x_test), digits=4)
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.908, total=   9.6s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    9.6s remaining:    0.0s
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.918, total=   9.6s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   19.1s remaining:    0.0s
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.903, total=   9.6s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.915, total=   9.7s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.912, total=   9.6s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.904, total=   9.6s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.915, total=   9.5s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.907, total=   9.7s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.903, total=   9.6s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.920, total=   9.6s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.829, total=  44.5s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.838, total=  48.5s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.829, total=  47.1s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.831, total=  46.9s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.831, total=  44.7s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.813, total=  46.3s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.845, total=  43.6s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.833, total=  45.3s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.830, total=  42.6s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.836, total=  42.4s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.794, total=  35.6s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.810, total=  35.1s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.796, total=  36.2s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.798, total=  35.9s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.795, total=  36.2s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.789, total=  36.7s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.814, total=  41.2s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.802, total=  37.9s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.798, total=  36.8s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.804, total=  37.5s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.889, total=   9.4s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.891, total=   9.3s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.884, total=   9.3s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.892, total=   9.4s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.891, total=   9.3s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.876, total=   9.3s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.901, total=   9.3s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.884, total=   9.5s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.882, total=   9.4s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.892, total=   9.3s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.853, total=  40.3s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.862, total=  40.0s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.851, total=  40.1s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.855, total=  39.6s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.860, total=  40.1s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.845, total=  40.0s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.869, total=  40.0s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.859, total=  39.3s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.855, total=  40.0s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.860, total=  39.9s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.898, total=  31.4s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.904, total=  32.1s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.890, total=  32.4s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.903, total=  32.5s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.909, total=  32.2s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.894, total=  35.8s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.914, total=  35.6s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.899, total=  35.7s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.900, total=  36.9s
# [CV] clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.907, total=  34.7s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.926, total=  10.0s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.932, total=  10.1s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.930, total=  10.3s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.934, total=  10.2s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.927, total=  10.2s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.924, total=   9.9s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.930, total=   9.9s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.931, total=  10.0s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.928, total=  10.1s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.938, total=   9.8s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.939, total=  49.3s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.942, total=  49.7s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.941, total=  49.0s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.944, total=  48.3s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.940, total=  46.4s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.938, total=  48.3s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.942, total=  47.5s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.945, total=  46.0s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.942, total=  45.8s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.950, total=  49.6s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.954, total=  38.2s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.958, total=  38.4s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.956, total=  38.0s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.958, total=  38.4s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.956, total=  39.0s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.952, total=  39.0s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.956, total=  37.7s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.958, total=  36.3s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.957, total=  36.5s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.963, total=  36.1s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.926, total=   9.4s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.933, total=   9.4s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.931, total=   9.4s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.934, total=   9.3s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.927, total=   9.2s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.926, total=   9.3s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.935, total=   9.3s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.937, total=   9.4s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.930, total=   9.4s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.940, total=   9.4s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.928, total=  39.2s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.937, total=  39.3s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.928, total=  39.6s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.938, total=  39.0s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.934, total=  39.5s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.928, total=  39.5s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.936, total=  40.2s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.931, total=  40.0s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.929, total=  40.7s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.939, total=  40.5s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.953, total=  32.8s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.956, total=  31.6s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.954, total=  31.6s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.957, total=  31.3s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.956, total=  31.1s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.952, total=  31.7s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.957, total=  31.1s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.955, total=  31.5s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.956, total=  31.3s
# [CV] clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.959, total=  31.3s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.921, total=   9.6s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.924, total=   9.5s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.924, total=   9.6s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.933, total=   9.5s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.924, total=   9.6s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.918, total=   9.6s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.927, total=   9.5s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.929, total=   9.6s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.926, total=   9.5s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.934, total=   9.6s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.932, total=  45.4s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.937, total=  45.8s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.931, total=  45.7s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.938, total=  47.1s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.933, total=  47.6s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.931, total=  46.7s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.940, total=  47.0s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.937, total=  45.8s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.936, total=  46.7s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.945, total=  43.9s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.948, total=  35.9s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.953, total=  35.5s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.948, total=  35.7s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.952, total=  35.4s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.949, total=  34.9s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.946, total=  35.4s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.953, total=  34.8s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.952, total=  35.5s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.950, total=  35.3s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.956, total=  35.7s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.921, total=   9.3s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.929, total=   9.2s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.922, total=   9.3s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.929, total=   9.3s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.924, total=   9.3s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.920, total=   9.3s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.926, total=   9.3s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.927, total=   9.3s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.922, total=   9.4s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.931, total=   9.3s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.928, total=  39.0s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.932, total=  39.8s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.922, total=  39.1s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.929, total=  39.1s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.929, total=  38.6s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.925, total=  39.3s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.933, total=  38.8s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.927, total=  39.0s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.924, total=  38.5s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.935, total=  39.1s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.951, total=  31.2s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.955, total=  30.5s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.954, total=  31.0s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.956, total=  30.5s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.953, total=  30.9s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.949, total=  30.7s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.958, total=  31.0s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.953, total=  31.1s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.952, total=  30.7s
# [CV] clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.957, total=  31.4s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.929, total=   9.5s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.937, total=   9.5s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.936, total=   9.4s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.941, total=   9.4s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.938, total=   9.4s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.931, total=   9.4s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.941, total=   9.4s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.938, total=   9.5s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.939, total=   9.5s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.943, total=   9.4s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.952, total=  44.2s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.959, total=  45.1s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.957, total=  44.4s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.958, total=  43.6s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.958, total=  44.3s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.954, total=  44.0s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.959, total=  44.0s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.960, total=  43.6s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.960, total=  43.6s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.965, total=  43.6s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.959, total=  36.6s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.968, total=  38.3s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.965, total=  37.7s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.964, total=  36.5s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.963, total=  36.8s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.964, total=  37.3s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.963, total=  36.7s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.966, total=  37.9s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.967, total=  36.1s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.972, total=  35.8s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.928, total=   9.1s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.941, total=   9.2s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.941, total=   9.2s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.940, total=   9.2s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.939, total=   9.2s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.935, total=   9.2s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.940, total=   9.2s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.942, total=   9.2s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.937, total=   9.1s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.944, total=   9.1s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.946, total=  38.5s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.954, total=  38.6s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.953, total=  38.8s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.953, total=  39.0s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.949, total=  38.5s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.945, total=  38.7s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.951, total=  38.4s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.958, total=  38.9s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.954, total=  39.3s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.961, total=  40.3s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.956, total=  31.8s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.967, total=  32.2s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.969, total=  32.2s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.965, total=  32.8s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.964, total=  32.7s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.966, total=  32.1s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.964, total=  32.6s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.968, total=  32.8s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.969, total=  32.3s
# [CV] clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.1, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.968, total=  33.6s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.923, total=   9.8s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.928, total=   9.7s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.930, total=   9.7s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.937, total=   9.7s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# ...
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.946, total=  39.1s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.949, total=  40.6s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.944, total=  40.2s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.943, total=  40.4s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.949, total=  39.7s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.948, total=  40.5s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.948, total=  40.3s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.959, total=  41.2s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.954, total=  33.5s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.963, total=  33.7s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.961, total=  34.9s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.964, total=  36.7s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.961, total=  33.2s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.960, total=  32.3s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.963, total=  32.9s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.963, total=  33.2s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.964, total=  36.0s
# [CV] clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l1, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.966, total=  31.6s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.936, total=   9.4s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.938, total=   9.4s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.939, total=   9.5s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.944, total=   9.5s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.941, total=   9.6s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.935, total=   9.7s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.945, total=   9.5s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.943, total=   9.7s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.943, total=   9.6s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 1), score=0.949, total=   9.5s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.958, total=  45.7s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.967, total=  44.8s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.965, total=  45.6s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.963, total=  46.4s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.964, total=  45.7s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.963, total=  46.5s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.964, total=  48.6s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.966, total=  46.6s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.966, total=  44.9s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(1, 2), score=0.970, total=  44.9s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.961, total=  36.5s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.969, total=  37.8s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.968, total=  36.4s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.968, total=  38.0s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.968, total=  38.0s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.968, total=  37.5s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.966, total=  37.0s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.966, total=  38.6s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.972, total=  38.5s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=True, vect__ngram_range=(2, 2), score=0.972, total=  38.4s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.935, total=  10.0s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.943, total=  10.0s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.944, total=  10.0s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.943, total=   9.8s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.943, total=   9.9s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.937, total=  10.0s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.944, total=  10.0s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.947, total=   9.7s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.944, total=   9.7s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 1), score=0.948, total=   9.6s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.954, total=  41.3s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.963, total=  40.9s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.962, total=  41.0s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.961, total=  41.3s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.961, total=  40.5s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.961, total=  40.6s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.962, total=  40.2s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.965, total=  39.5s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.965, total=  39.7s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(1, 2), score=0.970, total=  39.6s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.963, total=  31.5s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.970, total=  31.1s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.972, total=  31.4s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.969, total=  31.5s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.968, total=  32.1s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.967, total=  31.5s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.969, total=  32.2s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.971, total=  31.6s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.972, total=  31.7s
# [CV] clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2)
# [CV]  clf__alpha=0.01, tfidf__norm=l2, tfidf__use_idf=False, vect__ngram_range=(2, 2), score=0.975, total=  31.6s
# [Parallel(n_jobs=1)]: Done 360 out of 360 | elapsed: 175.4min finished
# '              precision    recall  f1-score   support\n\n           0     0.9679    0.9796    0.9737      7541\n           1     0.9779    0.9653    0.9715      7054\n\n    accuracy                         0.9727     14595\n   macro avg     0.9729    0.9724    0.9726     14595\nweighted avg     0.9727    0.9727    0.9727     14595\n'

# %%
predictions = clf.predict(x_test)

# %%
print(classification_report(y_test, predictions, digits=4, target_names=["fake", "true"]))
# Out:
#               precision    recall  f1-score   support
#
#         fake     0.9679    0.9796    0.9737      7541
#         true     0.9779    0.9653    0.9715      7054
#
#     accuracy                         0.9727     14595
#    macro avg     0.9729    0.9724    0.9726     14595
# weighted avg     0.9727    0.9727    0.9727     14595

# %%
clf.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('vect',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
#                                  ngram_range=(2, 2), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, vocabulary=None)),
#                 ('tfidf',
#                  TfidfTransformer(norm='l2', smooth_idf=True,
#                                   sublinear_tf=False, use_idf=False)),
#                 ('clf',
#                  MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True))],
#          verbose=False)

# %%
clf.best_params_
# Out:
# {'clf__alpha': 0.01,
#  'tfidf__norm': 'l2',
#  'tfidf__use_idf': False,
#  'vect__ngram_range': (2, 2)}

# %%
clf.best_score_
# Out:
# 0.9695253834630708

# %%
import joblib

# %%
joblib.dump(clf, "class_model.sav")
# Out:
# ['class_model.sav']

# %%
# !pip list

# %%
# !ls -lh
# Out:
# total 811M
# -rw-r--r--  1 root root 169M Aug 21 19:12 class_model.sav
# drwxr-xr-x  1 root root 4.0K Aug 13 13:35 sample_data
# drwxr-xr-x 13 1000 1000 4.0K May 24 05:00 spark-3.1.2-bin-hadoop2.7
# -rw-r--r--  1 root root 215M May 24 05:01 spark-3.1.2-bin-hadoop2.7.tgz
# -rw-r--r--  1 root root 215M May 24 05:01 spark-3.1.2-bin-hadoop2.7.tgz.1
# -rw-r--r--  1 root root 215M May 24 05:01 spark-3.1.2-bin-hadoop2.7.tgz.2

# %% [markdown]
# For connection in app.py for the project, need to used cloudpickle.dump in place of joblib.dump

# %%
import joblib

# %%
model = joblib.load('/content/drive/MyDrive/Colab Notebooks/class_model.sav')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import cloudpickle

# %%
with open("pickle_model.sav", mode="wb") as file:
  cloudpickle.dump(model, file)
